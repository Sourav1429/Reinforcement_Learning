# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourav1429/Reinforcement_Learning/blob/main/Advantage_actor_critic_Cartpole.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import torch  
import gym
import numpy as np  
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt
import pandas as pd

# hyperparameters
hidden_size = 256
learning_rate = 3e-4

# Constants
GAMMA = 0.99
num_steps = 300
max_episodes = 3000

# %%
class ActorCritic(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_size, learning_rate=3e-4):
        super(ActorCritic, self).__init__()

        self.num_actions = num_actions
        self.critic_linear1 = nn.Linear(num_inputs, hidden_size)
        self.critic_linear2 = nn.Linear(hidden_size, 1)

        self.actor_linear1 = nn.Linear(num_inputs, hidden_size)
        self.actor_linear2 = nn.Linear(hidden_size, num_actions)
    
    def forward(self, state):
        state = Variable(torch.from_numpy(state).float().unsqueeze(0))
        value = F.relu(self.critic_linear1(state))
        value = self.critic_linear2(value)
        
        policy_dist = F.relu(self.actor_linear1(state))
        policy_dist = F.softmax(self.actor_linear2(policy_dist), dim=1)

        return value, policy_dist

# %%
def a2c(env):
    num_inputs = env.observation_space.shape[0]
    num_outputs = env.action_space.n
    
    actor_critic = ActorCritic(num_inputs, num_outputs, hidden_size)
    ac_optimizer = optim.Adam(actor_critic.parameters(), lr=learning_rate)

    all_lengths = []
    average_lengths = []
    all_rewards = []
    entropy_term = 0

    for episode in range(max_episodes):
        log_probs = []
        values = []
        rewards = []

        state = env.reset()
        for steps in range(num_steps):
            #env.render();
            value, policy_dist = actor_critic.forward(state)
            value = value.detach().numpy()[0,0]
            dist = policy_dist.detach().numpy() 

            action = np.random.choice(num_outputs, p=np.squeeze(dist))
            log_prob = torch.log(policy_dist.squeeze(0)[action])
            entropy = -np.sum(np.mean(dist) * np.log(dist))
            new_state, reward, done, _ = env.step(action)

            rewards.append(reward)
            values.append(value)
            log_probs.append(log_prob)
            entropy_term += entropy
            state = new_state
            
            if done or steps == num_steps-1:
                Qval, _ = actor_critic.forward(new_state)
                Qval = Qval.detach().numpy()[0,0]
                all_rewards.append(np.sum(rewards))
                all_lengths.append(steps)
                average_lengths.append(np.mean(all_lengths[-10:]))
                if episode % 10 == 0:                    
                    sys.stdout.write("episode: {}, reward: {}, total length: {}, average length: {} \n".format(episode, np.sum(rewards), steps, average_lengths[-1]))
                break
        
        # compute Q values
        Qvals = np.zeros_like(values)
        for t in reversed(range(len(rewards))):
            Qval = rewards[t] + GAMMA * Qval
            Qvals[t] = Qval
  
        #update actor critic
        values = torch.FloatTensor(values)
        Qvals = torch.FloatTensor(Qvals)
        log_probs = torch.stack(log_probs)
        
        advantage = Qvals - values
        actor_loss = (-log_probs * advantage).mean()
        critic_loss = 0.5 * advantage.pow(2).mean()
        ac_loss = actor_loss + critic_loss + 0.001 * entropy_term

        ac_optimizer.zero_grad()
        ac_loss.backward()
        ac_optimizer.step()

        
    
    # Plot results
    smoothed_rewards = pd.Series.rolling(pd.Series(all_rewards), 10).mean()
    smoothed_rewards = [elem for elem in smoothed_rewards]
    plt.plot(all_rewards)
    plt.plot(smoothed_rewards)
    plt.plot()
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.show()

    plt.plot(all_lengths)
    plt.plot(average_lengths)
    plt.xlabel('Episode')
    plt.ylabel('Episode length')
    plt.show()

# %%
if __name__ == "__main__":
    env = gym.make("CartPole-v0")
    a2c(env)
# Out:
# episode: 0, reward: 28.0, total length: 27, average length: 27.0
# episode: 10, reward: 17.0, total length: 16, average length: 28.5
# episode: 20, reward: 16.0, total length: 15, average length: 21.0
# episode: 30, reward: 18.0, total length: 17, average length: 28.3
# episode: 40, reward: 12.0, total length: 11, average length: 17.9
# episode: 50, reward: 20.0, total length: 19, average length: 25.9
# episode: 60, reward: 54.0, total length: 53, average length: 22.0
# episode: 70, reward: 22.0, total length: 21, average length: 35.7
# episode: 80, reward: 27.0, total length: 26, average length: 23.2
# episode: 90, reward: 14.0, total length: 13, average length: 21.8
# episode: 100, reward: 92.0, total length: 91, average length: 31.1
# episode: 110, reward: 25.0, total length: 24, average length: 22.2
# episode: 120, reward: 46.0, total length: 45, average length: 27.1
# episode: 130, reward: 17.0, total length: 16, average length: 24.2
# episode: 140, reward: 27.0, total length: 26, average length: 33.6
# episode: 150, reward: 13.0, total length: 12, average length: 29.1
# episode: 160, reward: 83.0, total length: 82, average length: 34.3
# episode: 170, reward: 33.0, total length: 32, average length: 31.6
# episode: 180, reward: 83.0, total length: 82, average length: 42.2
# episode: 190, reward: 25.0, total length: 24, average length: 34.1
# episode: 200, reward: 24.0, total length: 23, average length: 41.7
# episode: 210, reward: 59.0, total length: 58, average length: 34.1
# episode: 220, reward: 21.0, total length: 20, average length: 26.5
# episode: 230, reward: 24.0, total length: 23, average length: 23.7
# episode: 240, reward: 27.0, total length: 26, average length: 35.1
# episode: 250, reward: 24.0, total length: 23, average length: 29.8
# episode: 260, reward: 39.0, total length: 38, average length: 45.2
# episode: 270, reward: 17.0, total length: 16, average length: 34.9
# episode: 280, reward: 11.0, total length: 10, average length: 28.5
# episode: 290, reward: 111.0, total length: 110, average length: 44.0
# episode: 300, reward: 30.0, total length: 29, average length: 37.7
# episode: 310, reward: 25.0, total length: 24, average length: 52.3
# episode: 320, reward: 50.0, total length: 49, average length: 56.5
# episode: 330, reward: 64.0, total length: 63, average length: 51.8
# episode: 340, reward: 24.0, total length: 23, average length: 39.1
# episode: 350, reward: 31.0, total length: 30, average length: 33.7
# episode: 360, reward: 94.0, total length: 93, average length: 46.7
# episode: 370, reward: 16.0, total length: 15, average length: 42.3
# episode: 380, reward: 40.0, total length: 39, average length: 39.9
# episode: 390, reward: 70.0, total length: 69, average length: 50.4
# episode: 400, reward: 19.0, total length: 18, average length: 33.4
# episode: 410, reward: 20.0, total length: 19, average length: 33.0
# episode: 420, reward: 40.0, total length: 39, average length: 36.2
# episode: 430, reward: 20.0, total length: 19, average length: 32.1
# episode: 440, reward: 90.0, total length: 89, average length: 49.0
# episode: 450, reward: 26.0, total length: 25, average length: 60.2
# episode: 460, reward: 73.0, total length: 72, average length: 50.6
# episode: 470, reward: 31.0, total length: 30, average length: 67.5
# episode: 480, reward: 32.0, total length: 31, average length: 38.0
# episode: 490, reward: 44.0, total length: 43, average length: 45.2
# episode: 500, reward: 86.0, total length: 85, average length: 49.0
# episode: 510, reward: 53.0, total length: 52, average length: 40.5
# episode: 520, reward: 50.0, total length: 49, average length: 60.3
# episode: 530, reward: 121.0, total length: 120, average length: 55.0
# episode: 540, reward: 80.0, total length: 79, average length: 40.5
# episode: 550, reward: 28.0, total length: 27, average length: 60.4
# episode: 560, reward: 57.0, total length: 56, average length: 75.6
# episode: 570, reward: 53.0, total length: 52, average length: 51.7
# episode: 580, reward: 72.0, total length: 71, average length: 70.5
# episode: 590, reward: 25.0, total length: 24, average length: 71.6
# episode: 600, reward: 29.0, total length: 28, average length: 62.0
# episode: 610, reward: 28.0, total length: 27, average length: 51.2
# episode: 620, reward: 63.0, total length: 62, average length: 72.4
# episode: 630, reward: 37.0, total length: 36, average length: 70.7
# episode: 640, reward: 21.0, total length: 20, average length: 73.0
# episode: 650, reward: 78.0, total length: 77, average length: 98.9
# episode: 660, reward: 79.0, total length: 78, average length: 77.5
# episode: 670, reward: 113.0, total length: 112, average length: 72.3
# episode: 680, reward: 21.0, total length: 20, average length: 66.5
# episode: 690, reward: 30.0, total length: 29, average length: 90.0
# episode: 700, reward: 162.0, total length: 161, average length: 59.4
# episode: 710, reward: 53.0, total length: 52, average length: 56.5
# episode: 720, reward: 200.0, total length: 199, average length: 70.0
# episode: 730, reward: 75.0, total length: 74, average length: 59.4
# episode: 740, reward: 52.0, total length: 51, average length: 70.5
# episode: 750, reward: 76.0, total length: 75, average length: 85.0
# episode: 760, reward: 23.0, total length: 22, average length: 74.0
# episode: 770, reward: 183.0, total length: 182, average length: 101.0
# episode: 780, reward: 58.0, total length: 57, average length: 97.6
# episode: 790, reward: 63.0, total length: 62, average length: 78.6
# episode: 800, reward: 148.0, total length: 147, average length: 77.2
# episode: 810, reward: 104.0, total length: 103, average length: 92.0
# episode: 820, reward: 21.0, total length: 20, average length: 56.7
# episode: 830, reward: 27.0, total length: 26, average length: 73.2
# episode: 840, reward: 34.0, total length: 33, average length: 75.3
# episode: 850, reward: 41.0, total length: 40, average length: 94.5
# episode: 860, reward: 148.0, total length: 147, average length: 64.9
# episode: 870, reward: 93.0, total length: 92, average length: 87.4
# episode: 880, reward: 28.0, total length: 27, average length: 85.7
# episode: 890, reward: 41.0, total length: 40, average length: 75.2
# episode: 900, reward: 54.0, total length: 53, average length: 60.4
# episode: 910, reward: 187.0, total length: 186, average length: 135.0
# episode: 920, reward: 200.0, total length: 199, average length: 106.3
# episode: 930, reward: 97.0, total length: 96, average length: 95.0
# episode: 940, reward: 32.0, total length: 31, average length: 97.8
# episode: 950, reward: 137.0, total length: 136, average length: 102.7
# episode: 960, reward: 32.0, total length: 31, average length: 116.9
# episode: 970, reward: 200.0, total length: 199, average length: 107.4
# episode: 980, reward: 127.0, total length: 126, average length: 101.5
# episode: 990, reward: 27.0, total length: 26, average length: 142.1
# episode: 1000, reward: 200.0, total length: 199, average length: 112.5
# episode: 1010, reward: 17.0, total length: 16, average length: 120.8
# episode: 1020, reward: 65.0, total length: 64, average length: 142.0
# episode: 1030, reward: 200.0, total length: 199, average length: 137.8
# episode: 1040, reward: 200.0, total length: 199, average length: 130.9
# episode: 1050, reward: 122.0, total length: 121, average length: 144.0
# episode: 1060, reward: 125.0, total length: 124, average length: 107.6
# episode: 1070, reward: 142.0, total length: 141, average length: 118.6
# episode: 1080, reward: 181.0, total length: 180, average length: 109.6
# episode: 1090, reward: 113.0, total length: 112, average length: 137.6
# episode: 1100, reward: 195.0, total length: 194, average length: 124.0
# episode: 1110, reward: 162.0, total length: 161, average length: 160.1
# episode: 1120, reward: 138.0, total length: 137, average length: 133.1
# episode: 1130, reward: 98.0, total length: 97, average length: 162.2
# episode: 1140, reward: 27.0, total length: 26, average length: 96.3
# episode: 1150, reward: 119.0, total length: 118, average length: 133.8
# episode: 1160, reward: 34.0, total length: 33, average length: 110.8
# episode: 1170, reward: 65.0, total length: 64, average length: 111.1
# episode: 1180, reward: 134.0, total length: 133, average length: 131.1
# episode: 1190, reward: 41.0, total length: 40, average length: 66.9
# episode: 1200, reward: 106.0, total length: 105, average length: 115.3
# episode: 1210, reward: 156.0, total length: 155, average length: 139.0
# episode: 1220, reward: 62.0, total length: 61, average length: 94.2
# episode: 1230, reward: 39.0, total length: 38, average length: 124.5
# episode: 1240, reward: 53.0, total length: 52, average length: 95.4
# episode: 1250, reward: 107.0, total length: 106, average length: 98.2
# episode: 1260, reward: 152.0, total length: 151, average length: 133.5
# episode: 1270, reward: 126.0, total length: 125, average length: 95.4
# episode: 1280, reward: 173.0, total length: 172, average length: 117.7
# episode: 1290, reward: 154.0, total length: 153, average length: 120.6
# episode: 1300, reward: 200.0, total length: 199, average length: 121.8
# episode: 1310, reward: 169.0, total length: 168, average length: 149.9
# episode: 1320, reward: 168.0, total length: 167, average length: 138.5
# episode: 1330, reward: 118.0, total length: 117, average length: 118.4
# episode: 1340, reward: 145.0, total length: 144, average length: 143.1
# episode: 1350, reward: 200.0, total length: 199, average length: 149.5
# episode: 1360, reward: 200.0, total length: 199, average length: 167.9
# episode: 1370, reward: 41.0, total length: 40, average length: 171.9
# episode: 1380, reward: 200.0, total length: 199, average length: 163.9
# episode: 1390, reward: 153.0, total length: 152, average length: 176.4
# episode: 1400, reward: 200.0, total length: 199, average length: 163.0
# episode: 1410, reward: 186.0, total length: 185, average length: 170.0
# episode: 1420, reward: 187.0, total length: 186, average length: 189.7
# episode: 1430, reward: 200.0, total length: 199, average length: 184.0
# episode: 1440, reward: 188.0, total length: 187, average length: 160.0
# episode: 1450, reward: 112.0, total length: 111, average length: 163.4
# episode: 1460, reward: 135.0, total length: 134, average length: 162.5
# episode: 1470, reward: 112.0, total length: 111, average length: 143.7
# episode: 1480, reward: 200.0, total length: 199, average length: 161.9
# episode: 1490, reward: 174.0, total length: 173, average length: 166.1
# episode: 1500, reward: 116.0, total length: 115, average length: 164.7
# episode: 1510, reward: 200.0, total length: 199, average length: 179.4
# episode: 1520, reward: 158.0, total length: 157, average length: 167.5
# episode: 1530, reward: 189.0, total length: 188, average length: 192.5
# episode: 1540, reward: 200.0, total length: 199, average length: 194.4
# episode: 1550, reward: 194.0, total length: 193, average length: 185.6
# episode: 1560, reward: 178.0, total length: 177, average length: 180.7
# episode: 1570, reward: 121.0, total length: 120, average length: 174.5
# episode: 1580, reward: 118.0, total length: 117, average length: 173.9
# episode: 1590, reward: 200.0, total length: 199, average length: 190.5
# episode: 1600, reward: 200.0, total length: 199, average length: 177.6
# episode: 1610, reward: 112.0, total length: 111, average length: 175.6
# episode: 1620, reward: 180.0, total length: 179, average length: 190.6
# episode: 1630, reward: 200.0, total length: 199, average length: 178.4
# episode: 1640, reward: 200.0, total length: 199, average length: 187.0
# episode: 1650, reward: 200.0, total length: 199, average length: 179.8
# episode: 1660, reward: 135.0, total length: 134, average length: 182.8
# episode: 1670, reward: 200.0, total length: 199, average length: 179.6
# episode: 1680, reward: 200.0, total length: 199, average length: 177.3
# episode: 1690, reward: 200.0, total length: 199, average length: 187.6
# episode: 1700, reward: 44.0, total length: 43, average length: 149.1
# episode: 1710, reward: 169.0, total length: 168, average length: 182.3
# episode: 1720, reward: 178.0, total length: 177, average length: 189.1
# episode: 1730, reward: 200.0, total length: 199, average length: 162.6
# episode: 1740, reward: 134.0, total length: 133, average length: 162.5
# episode: 1750, reward: 200.0, total length: 199, average length: 170.8
# episode: 1760, reward: 26.0, total length: 25, average length: 160.8
# episode: 1770, reward: 200.0, total length: 199, average length: 169.5
# episode: 1780, reward: 200.0, total length: 199, average length: 177.8
# episode: 1790, reward: 200.0, total length: 199, average length: 180.3
# episode: 1800, reward: 200.0, total length: 199, average length: 191.2
# episode: 1810, reward: 200.0, total length: 199, average length: 181.8
# episode: 1820, reward: 200.0, total length: 199, average length: 184.6
# episode: 1830, reward: 158.0, total length: 157, average length: 186.2
# episode: 1840, reward: 200.0, total length: 199, average length: 178.3
# episode: 1850, reward: 200.0, total length: 199, average length: 166.0
# episode: 1860, reward: 200.0, total length: 199, average length: 170.8
# episode: 1870, reward: 200.0, total length: 199, average length: 183.0
# episode: 1880, reward: 200.0, total length: 199, average length: 188.3
# episode: 1890, reward: 144.0, total length: 143, average length: 165.8
# episode: 1900, reward: 200.0, total length: 199, average length: 189.9
# episode: 1910, reward: 200.0, total length: 199, average length: 191.1
# episode: 1920, reward: 92.0, total length: 91, average length: 172.8
# episode: 1930, reward: 200.0, total length: 199, average length: 186.2
# episode: 1940, reward: 200.0, total length: 199, average length: 181.7
# episode: 1950, reward: 200.0, total length: 199, average length: 171.5
# episode: 1960, reward: 200.0, total length: 199, average length: 171.8
# episode: 1970, reward: 153.0, total length: 152, average length: 153.0
# episode: 1980, reward: 137.0, total length: 136, average length: 165.5
# episode: 1990, reward: 200.0, total length: 199, average length: 144.3
# episode: 2000, reward: 200.0, total length: 199, average length: 192.8
# episode: 2010, reward: 200.0, total length: 199, average length: 177.3
# episode: 2020, reward: 149.0, total length: 148, average length: 177.8
# episode: 2030, reward: 200.0, total length: 199, average length: 189.7
# episode: 2040, reward: 198.0, total length: 197, average length: 181.0
# episode: 2050, reward: 157.0, total length: 156, average length: 183.1
# episode: 2060, reward: 172.0, total length: 171, average length: 175.6
# episode: 2070, reward: 154.0, total length: 153, average length: 185.3
# episode: 2080, reward: 200.0, total length: 199, average length: 181.4
# episode: 2090, reward: 200.0, total length: 199, average length: 179.3
# episode: 2100, reward: 200.0, total length: 199, average length: 172.1
# episode: 2110, reward: 200.0, total length: 199, average length: 175.2
# episode: 2120, reward: 200.0, total length: 199, average length: 187.5
# episode: 2130, reward: 200.0, total length: 199, average length: 187.6
# episode: 2140, reward: 200.0, total length: 199, average length: 170.9
# episode: 2150, reward: 61.0, total length: 60, average length: 160.7
# episode: 2160, reward: 134.0, total length: 133, average length: 173.4
# episode: 2170, reward: 200.0, total length: 199, average length: 167.3
# episode: 2180, reward: 200.0, total length: 199, average length: 182.9
# episode: 2190, reward: 187.0, total length: 186, average length: 167.4
# episode: 2200, reward: 200.0, total length: 199, average length: 171.1
# episode: 2210, reward: 200.0, total length: 199, average length: 171.9
# episode: 2220, reward: 200.0, total length: 199, average length: 185.5
# episode: 2230, reward: 120.0, total length: 119, average length: 167.1
# episode: 2240, reward: 200.0, total length: 199, average length: 178.7
# episode: 2250, reward: 150.0, total length: 149, average length: 163.3
# episode: 2260, reward: 200.0, total length: 199, average length: 170.3
# episode: 2270, reward: 200.0, total length: 199, average length: 183.3
# episode: 2280, reward: 146.0, total length: 145, average length: 181.2
# episode: 2290, reward: 200.0, total length: 199, average length: 170.5
# episode: 2300, reward: 128.0, total length: 127, average length: 190.0
# episode: 2310, reward: 172.0, total length: 171, average length: 173.1
# episode: 2320, reward: 200.0, total length: 199, average length: 196.0
# episode: 2330, reward: 200.0, total length: 199, average length: 197.5
# episode: 2340, reward: 200.0, total length: 199, average length: 194.7
# episode: 2350, reward: 178.0, total length: 177, average length: 196.8
# episode: 2360, reward: 200.0, total length: 199, average length: 199.0
# episode: 2370, reward: 200.0, total length: 199, average length: 196.5
# episode: 2380, reward: 200.0, total length: 199, average length: 197.7
# episode: 2390, reward: 200.0, total length: 199, average length: 192.6
# episode: 2400, reward: 200.0, total length: 199, average length: 177.3
# episode: 2410, reward: 148.0, total length: 147, average length: 170.3
# episode: 2420, reward: 132.0, total length: 131, average length: 175.8
# episode: 2430, reward: 200.0, total length: 199, average length: 184.8
# episode: 2440, reward: 132.0, total length: 131, average length: 170.5
# episode: 2450, reward: 109.0, total length: 108, average length: 160.2
# episode: 2460, reward: 159.0, total length: 158, average length: 163.1
# episode: 2470, reward: 200.0, total length: 199, average length: 156.8
# episode: 2480, reward: 131.0, total length: 130, average length: 134.7
# episode: 2490, reward: 189.0, total length: 188, average length: 166.2
# episode: 2500, reward: 50.0, total length: 49, average length: 126.4
# episode: 2510, reward: 129.0, total length: 128, average length: 138.4
# episode: 2520, reward: 189.0, total length: 188, average length: 143.1
# episode: 2530, reward: 117.0, total length: 116, average length: 167.2
# episode: 2540, reward: 153.0, total length: 152, average length: 171.2
# episode: 2550, reward: 200.0, total length: 199, average length: 158.9
# episode: 2560, reward: 200.0, total length: 199, average length: 173.6
# episode: 2570, reward: 200.0, total length: 199, average length: 190.6
# episode: 2580, reward: 146.0, total length: 145, average length: 184.8
# episode: 2590, reward: 200.0, total length: 199, average length: 166.3
# episode: 2600, reward: 171.0, total length: 170, average length: 174.4
# episode: 2610, reward: 200.0, total length: 199, average length: 195.9
# episode: 2620, reward: 176.0, total length: 175, average length: 187.5
# episode: 2630, reward: 200.0, total length: 199, average length: 192.6
# episode: 2640, reward: 200.0, total length: 199, average length: 199.0
# episode: 2650, reward: 200.0, total length: 199, average length: 192.6
# episode: 2660, reward: 200.0, total length: 199, average length: 175.6
# episode: 2670, reward: 200.0, total length: 199, average length: 186.5
# episode: 2680, reward: 200.0, total length: 199, average length: 196.0
# episode: 2690, reward: 200.0, total length: 199, average length: 194.4
# episode: 2700, reward: 200.0, total length: 199, average length: 181.9
# episode: 2710, reward: 200.0, total length: 199, average length: 199.0
# episode: 2720, reward: 200.0, total length: 199, average length: 199.0
# episode: 2730, reward: 200.0, total length: 199, average length: 185.6
# episode: 2740, reward: 200.0, total length: 199, average length: 199.0
# episode: 2750, reward: 74.0, total length: 73, average length: 172.5
# episode: 2760, reward: 200.0, total length: 199, average length: 189.7
# episode: 2770, reward: 141.0, total length: 140, average length: 176.6
# episode: 2780, reward: 124.0, total length: 123, average length: 177.4
# episode: 2790, reward: 200.0, total length: 199, average length: 189.7
# episode: 2800, reward: 200.0, total length: 199, average length: 188.8
# episode: 2810, reward: 200.0, total length: 199, average length: 174.3
# episode: 2820, reward: 200.0, total length: 199, average length: 198.4
# episode: 2830, reward: 200.0, total length: 199, average length: 188.6
# episode: 2840, reward: 200.0, total length: 199, average length: 190.2
# episode: 2850, reward: 200.0, total length: 199, average length: 172.5
# episode: 2860, reward: 185.0, total length: 184, average length: 183.4
# episode: 2870, reward: 200.0, total length: 199, average length: 199.0
# episode: 2880, reward: 200.0, total length: 199, average length: 191.9
# episode: 2890, reward: 82.0, total length: 81, average length: 176.7
# episode: 2900, reward: 179.0, total length: 178, average length: 183.1
# episode: 2910, reward: 200.0, total length: 199, average length: 191.8
# episode: 2920, reward: 200.0, total length: 199, average length: 193.2
# episode: 2930, reward: 200.0, total length: 199, average length: 189.2
# episode: 2940, reward: 200.0, total length: 199, average length: 174.8
# episode: 2950, reward: 200.0, total length: 199, average length: 183.0
# episode: 2960, reward: 115.0, total length: 114, average length: 165.1
# episode: 2970, reward: 148.0, total length: 147, average length: 156.6
# episode: 2980, reward: 200.0, total length: 199, average length: 165.4
# episode: 2990, reward: 180.0, total length: 179, average length: 173.5
