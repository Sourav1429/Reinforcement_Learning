# %%
import gym, os
from itertools import count
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
env = gym.make("CartPole-v0").unwrapped

state_size = env.observation_space.shape[0]
action_size = env.action_space.n
lr = 0.0001

# %%
class Actor(nn.Module):
    def __init__(self, state_size, action_size):
        super(Actor, self).__init__()
        self.state_size = state_size
        self.action_size = action_size
        self.linear1 = nn.Linear(self.state_size, 128)
        #self.linear2 = nn.Linear(128, 256)
        self.linear3 = nn.Linear(128, self.action_size)

    def forward(self, state):
        output = F.relu(self.linear1(state))
        #output = F.relu(self.linear2(output))
        output = self.linear3(output)
        distribution = Categorical(F.softmax(output, dim=-1))
        return distribution

# %%
class Critic(nn.Module):
    def __init__(self, state_size, action_size):
        super(Critic, self).__init__()
        self.state_size = state_size
        self.action_size = action_size
        self.linear1 = nn.Linear(self.state_size, 128)
        #self.linear2 = nn.Linear(128, 256)
        self.linear3 = nn.Linear(128, 1)

    def forward(self, state):
        output = F.relu(self.linear1(state))
        #output = F.relu(self.linear2(output))
        value = self.linear3(output)
        return value

# %%
def compute_returns(next_value, rewards, masks, gamma=0.99):
    R = next_value
    returns = []
    for step in reversed(range(len(rewards))):
        R = rewards[step] + gamma * R * masks[step]
        returns.insert(0, R)
    return returns

# %%
def trainIters(actor, critic, n_iters):
    optimizerA = optim.Adam(actor.parameters())
    optimizerC = optim.Adam(critic.parameters())
    for iter in range(n_iters):
        state = env.reset()
        log_probs = []
        values = []
        rewards = []
        masks = []
        entropy = 0
        env.reset()

        for i in count():
            #env.render()
            state = torch.FloatTensor(state).to(device)
            dist, value = actor.forward(state), critic.forward(state)

            action = dist.sample()
            next_state, reward, done, _ = env.step(action.cpu().numpy())

            log_prob = dist.log_prob(action).unsqueeze(0)
            entropy += dist.entropy().mean()

            log_probs.append(log_prob)
            values.append(value)
            rewards.append(torch.tensor([reward], dtype=torch.float, device=device))
            masks.append(torch.tensor([1-done], dtype=torch.float, device=device))

            state = next_state

            if done:
                print('Iteration: {}, Score: {}'.format(iter, i))
                break


        next_state = torch.FloatTensor(next_state).to(device)
        next_value = critic(next_state)
        returns = compute_returns(next_value, rewards, masks)

        log_probs = torch.cat(log_probs)
        returns = torch.cat(returns).detach()
        values = torch.cat(values)

        advantage = returns - values

        actor_loss = -(log_probs * advantage.detach()).mean()
        critic_loss = advantage.pow(2).mean()

        optimizerA.zero_grad()
        optimizerC.zero_grad()
        actor_loss.backward()
        critic_loss.backward()
        optimizerA.step()
        optimizerC.step()
    torch.save(actor, 'actor.pkl')
    torch.save(critic, 'critic.pkl')
    env.close()

# %%
if __name__ == '__main__':
    if os.path.exists('model/actor.pkl'):
        actor = torch.load('model/actor.pkl')
        print('Actor Model loaded')
    else:
        actor = Actor(state_size, action_size).to(device)
    if os.path.exists('model/critic.pkl'):
        critic = torch.load('model/critic.pkl')
        print('Critic Model loaded')
    else:
        critic = Critic(state_size, action_size).to(device)
    trainIters(actor, critic, n_iters=500)
# Out:
# Iteration: 0, Score: 10
# Iteration: 1, Score: 12
# Iteration: 2, Score: 12
# Iteration: 3, Score: 13
# Iteration: 4, Score: 13
# Iteration: 5, Score: 14
# Iteration: 6, Score: 13
# Iteration: 7, Score: 9
# Iteration: 8, Score: 17
# Iteration: 9, Score: 14
# Iteration: 10, Score: 13
# Iteration: 11, Score: 13
# Iteration: 12, Score: 11
# Iteration: 13, Score: 33
# Iteration: 14, Score: 17
# Iteration: 15, Score: 24
# Iteration: 16, Score: 11
# Iteration: 17, Score: 29
# Iteration: 18, Score: 21
# Iteration: 19, Score: 14
# Iteration: 20, Score: 10
# Iteration: 21, Score: 8
# Iteration: 22, Score: 20
# Iteration: 23, Score: 13
# Iteration: 24, Score: 29
# Iteration: 25, Score: 19
# Iteration: 26, Score: 17
# Iteration: 27, Score: 15
# Iteration: 28, Score: 18
# Iteration: 29, Score: 31
# Iteration: 30, Score: 10
# Iteration: 31, Score: 12
# Iteration: 32, Score: 9
# Iteration: 33, Score: 14
# Iteration: 34, Score: 15
# Iteration: 35, Score: 31
# Iteration: 36, Score: 15
# Iteration: 37, Score: 11
# Iteration: 38, Score: 14
# Iteration: 39, Score: 18
# Iteration: 40, Score: 12
# Iteration: 41, Score: 24
# Iteration: 42, Score: 12
# Iteration: 43, Score: 26
# Iteration: 44, Score: 13
# Iteration: 45, Score: 18
# Iteration: 46, Score: 24
# Iteration: 47, Score: 13
# Iteration: 48, Score: 10
# Iteration: 49, Score: 20
# Iteration: 50, Score: 39
# Iteration: 51, Score: 26
# Iteration: 52, Score: 22
# Iteration: 53, Score: 14
# Iteration: 54, Score: 31
# Iteration: 55, Score: 12
# Iteration: 56, Score: 10
# Iteration: 57, Score: 11
# Iteration: 58, Score: 12
# Iteration: 59, Score: 17
# Iteration: 60, Score: 15
# Iteration: 61, Score: 16
# Iteration: 62, Score: 25
# Iteration: 63, Score: 8
# Iteration: 64, Score: 26
# Iteration: 65, Score: 42
# Iteration: 66, Score: 14
# Iteration: 67, Score: 18
# Iteration: 68, Score: 37
# Iteration: 69, Score: 13
# Iteration: 70, Score: 13
# Iteration: 71, Score: 15
# Iteration: 72, Score: 31
# Iteration: 73, Score: 13
# Iteration: 74, Score: 14
# Iteration: 75, Score: 9
# Iteration: 76, Score: 17
# Iteration: 77, Score: 22
# Iteration: 78, Score: 14
# Iteration: 79, Score: 12
# Iteration: 80, Score: 20
# Iteration: 81, Score: 35
# Iteration: 82, Score: 38
# Iteration: 83, Score: 21
# Iteration: 84, Score: 22
# Iteration: 85, Score: 10
# Iteration: 86, Score: 11
# Iteration: 87, Score: 16
# Iteration: 88, Score: 40
# Iteration: 89, Score: 31
# Iteration: 90, Score: 48
# Iteration: 91, Score: 59
# Iteration: 92, Score: 27
# Iteration: 93, Score: 12
# Iteration: 94, Score: 27
# Iteration: 95, Score: 20
# Iteration: 96, Score: 22
# Iteration: 97, Score: 33
# Iteration: 98, Score: 39
# Iteration: 99, Score: 46
# Iteration: 100, Score: 21
# Iteration: 101, Score: 24
# Iteration: 102, Score: 37
# Iteration: 103, Score: 22
# Iteration: 104, Score: 30
# Iteration: 105, Score: 15
# Iteration: 106, Score: 11
# Iteration: 107, Score: 33
# Iteration: 108, Score: 19
# Iteration: 109, Score: 18
# Iteration: 110, Score: 23
# Iteration: 111, Score: 24
# Iteration: 112, Score: 21
# Iteration: 113, Score: 32
# Iteration: 114, Score: 51
# Iteration: 115, Score: 89
# Iteration: 116, Score: 26
# Iteration: 117, Score: 15
# Iteration: 118, Score: 23
# Iteration: 119, Score: 12
# Iteration: 120, Score: 42
# Iteration: 121, Score: 19
# Iteration: 122, Score: 11
# Iteration: 123, Score: 19
# Iteration: 124, Score: 23
# Iteration: 125, Score: 9
# Iteration: 126, Score: 47
# Iteration: 127, Score: 19
# Iteration: 128, Score: 25
# Iteration: 129, Score: 14
# Iteration: 130, Score: 27
# Iteration: 131, Score: 33
# Iteration: 132, Score: 10
# Iteration: 133, Score: 20
# Iteration: 134, Score: 10
# Iteration: 135, Score: 76
# Iteration: 136, Score: 28
# Iteration: 137, Score: 27
# Iteration: 138, Score: 30
# Iteration: 139, Score: 45
# Iteration: 140, Score: 24
# Iteration: 141, Score: 34
# Iteration: 142, Score: 35
# Iteration: 143, Score: 17
# Iteration: 144, Score: 27
# Iteration: 145, Score: 33
# Iteration: 146, Score: 22
# Iteration: 147, Score: 46
# Iteration: 148, Score: 25
# Iteration: 149, Score: 14
# Iteration: 150, Score: 25
# Iteration: 151, Score: 15
# Iteration: 152, Score: 14
# Iteration: 153, Score: 22
# Iteration: 154, Score: 18
# Iteration: 155, Score: 26
# Iteration: 156, Score: 35
# Iteration: 157, Score: 37
# Iteration: 158, Score: 21
# Iteration: 159, Score: 40
# Iteration: 160, Score: 28
# Iteration: 161, Score: 39
# Iteration: 162, Score: 52
# Iteration: 163, Score: 70
# Iteration: 164, Score: 31
# Iteration: 165, Score: 78
# Iteration: 166, Score: 49
# Iteration: 167, Score: 37
# Iteration: 168, Score: 22
# Iteration: 169, Score: 73
# Iteration: 170, Score: 18
# Iteration: 171, Score: 86
# Iteration: 172, Score: 20
# Iteration: 173, Score: 25
# Iteration: 174, Score: 41
# Iteration: 175, Score: 20
# Iteration: 176, Score: 14
# Iteration: 177, Score: 44
# Iteration: 178, Score: 12
# Iteration: 179, Score: 40
# Iteration: 180, Score: 21
# Iteration: 181, Score: 39
# Iteration: 182, Score: 39
# Iteration: 183, Score: 74
# Iteration: 184, Score: 38
# Iteration: 185, Score: 13
# Iteration: 186, Score: 19
# Iteration: 187, Score: 25
# Iteration: 188, Score: 52
# Iteration: 189, Score: 9
# Iteration: 190, Score: 21
# Iteration: 191, Score: 15
# Iteration: 192, Score: 102
# Iteration: 193, Score: 25
# Iteration: 194, Score: 45
# Iteration: 195, Score: 63
# Iteration: 196, Score: 124
# Iteration: 197, Score: 25
# Iteration: 198, Score: 22
# Iteration: 199, Score: 80
# Iteration: 200, Score: 28
# Iteration: 201, Score: 79
# Iteration: 202, Score: 50
# Iteration: 203, Score: 32
# Iteration: 204, Score: 104
# Iteration: 205, Score: 47
# Iteration: 206, Score: 30
# Iteration: 207, Score: 131
# Iteration: 208, Score: 74
# Iteration: 209, Score: 84
# Iteration: 210, Score: 66
# Iteration: 211, Score: 64
# Iteration: 212, Score: 43
# Iteration: 213, Score: 24
# Iteration: 214, Score: 71
# Iteration: 215, Score: 23
# Iteration: 216, Score: 15
# Iteration: 217, Score: 83
# Iteration: 218, Score: 62
# Iteration: 219, Score: 71
# Iteration: 220, Score: 87
# Iteration: 221, Score: 31
# Iteration: 222, Score: 46
# Iteration: 223, Score: 131
# Iteration: 224, Score: 20
# Iteration: 225, Score: 20
# Iteration: 226, Score: 79
# Iteration: 227, Score: 47
# Iteration: 228, Score: 50
# Iteration: 229, Score: 50
# Iteration: 230, Score: 47
# Iteration: 231, Score: 161
# Iteration: 232, Score: 44
# Iteration: 233, Score: 27
# Iteration: 234, Score: 37
# Iteration: 235, Score: 33
# Iteration: 236, Score: 35
# Iteration: 237, Score: 43
# Iteration: 238, Score: 58
# Iteration: 239, Score: 56
# Iteration: 240, Score: 92
# Iteration: 241, Score: 94
# Iteration: 242, Score: 47
# Iteration: 243, Score: 25
# Iteration: 244, Score: 32
# Iteration: 245, Score: 31
# Iteration: 246, Score: 70
# Iteration: 247, Score: 53
# Iteration: 248, Score: 43
# Iteration: 249, Score: 66
# Iteration: 250, Score: 141
# Iteration: 251, Score: 113
# Iteration: 252, Score: 145
# Iteration: 253, Score: 88
# Iteration: 254, Score: 120
# Iteration: 255, Score: 32
# Iteration: 256, Score: 61
# Iteration: 257, Score: 86
# Iteration: 258, Score: 23
# Iteration: 259, Score: 36
# Iteration: 260, Score: 167
# Iteration: 261, Score: 51
# Iteration: 262, Score: 83
# Iteration: 263, Score: 177
# Iteration: 264, Score: 200
# Iteration: 265, Score: 133
# Iteration: 266, Score: 60
# Iteration: 267, Score: 55
# Iteration: 268, Score: 92
# Iteration: 269, Score: 113
# Iteration: 270, Score: 117
# Iteration: 271, Score: 21
# Iteration: 272, Score: 35
# Iteration: 273, Score: 137
# Iteration: 274, Score: 75
# Iteration: 275, Score: 207
# Iteration: 276, Score: 173
# Iteration: 277, Score: 253
# Iteration: 278, Score: 89
# Iteration: 279, Score: 126
# Iteration: 280, Score: 128
# Iteration: 281, Score: 214
# Iteration: 282, Score: 52
# Iteration: 283, Score: 90
# Iteration: 284, Score: 88
# Iteration: 285, Score: 33
# Iteration: 286, Score: 87
# Iteration: 287, Score: 42
# Iteration: 288, Score: 365
# Iteration: 289, Score: 138
# Iteration: 290, Score: 212
# Iteration: 291, Score: 32
# Iteration: 292, Score: 122
# Iteration: 293, Score: 128
# Iteration: 294, Score: 87
# Iteration: 295, Score: 49
# Iteration: 296, Score: 140
# Iteration: 297, Score: 151
# Iteration: 298, Score: 81
# Iteration: 299, Score: 236
# Iteration: 300, Score: 124
# Iteration: 301, Score: 381
# Iteration: 302, Score: 176
# Iteration: 303, Score: 49
# Iteration: 304, Score: 51
# Iteration: 305, Score: 203
# Iteration: 306, Score: 197
# Iteration: 307, Score: 263
# Iteration: 308, Score: 242
# Iteration: 309, Score: 101
# Iteration: 310, Score: 46
# Iteration: 311, Score: 141
# Iteration: 312, Score: 137
# Iteration: 313, Score: 260
# Iteration: 314, Score: 21
# Iteration: 315, Score: 42
# Iteration: 316, Score: 100
# Iteration: 317, Score: 90
# Iteration: 318, Score: 125
# Iteration: 319, Score: 172
# Iteration: 320, Score: 158
# Iteration: 321, Score: 202
# Iteration: 322, Score: 155
# Iteration: 323, Score: 217
# Iteration: 324, Score: 78
# Iteration: 325, Score: 205
# Iteration: 326, Score: 255
# Iteration: 327, Score: 199
# Iteration: 328, Score: 143
# Iteration: 329, Score: 174
# Iteration: 330, Score: 205
# Iteration: 331, Score: 186
# Iteration: 332, Score: 198
# Iteration: 333, Score: 154
# Iteration: 334, Score: 214
# Iteration: 335, Score: 172
# Iteration: 336, Score: 180
# Iteration: 337, Score: 452
# Iteration: 338, Score: 114
# Iteration: 339, Score: 218
# Iteration: 340, Score: 473
# Iteration: 341, Score: 415
# Iteration: 342, Score: 196
# Iteration: 343, Score: 359
# Iteration: 344, Score: 321
# Iteration: 345, Score: 271
# Iteration: 346, Score: 343
# Iteration: 347, Score: 294
# Iteration: 348, Score: 138
# Iteration: 349, Score: 176
# Iteration: 350, Score: 156
# Iteration: 351, Score: 339
# Iteration: 352, Score: 335
# Iteration: 353, Score: 397
# Iteration: 354, Score: 162
# Iteration: 355, Score: 387
# Iteration: 356, Score: 199
# Iteration: 357, Score: 397
# Iteration: 358, Score: 150
# Iteration: 359, Score: 61
# Iteration: 360, Score: 647
# Iteration: 361, Score: 268
# Iteration: 362, Score: 304
# Iteration: 363, Score: 108
# Iteration: 364, Score: 803
# Iteration: 365, Score: 236
# Iteration: 366, Score: 115
# Iteration: 367, Score: 164
# Iteration: 368, Score: 281
# Iteration: 369, Score: 259
# Iteration: 370, Score: 490
# Iteration: 371, Score: 404
# Iteration: 372, Score: 248
# Iteration: 373, Score: 176
# Iteration: 374, Score: 371
# Iteration: 375, Score: 208
# Iteration: 376, Score: 179
# Iteration: 377, Score: 417
# Iteration: 378, Score: 448
# Iteration: 379, Score: 464
# Iteration: 380, Score: 280
# Iteration: 381, Score: 160
# Iteration: 382, Score: 216
# Iteration: 383, Score: 242
# Iteration: 384, Score: 520
# Iteration: 385, Score: 250
# Iteration: 386, Score: 288
# Iteration: 387, Score: 266
# Iteration: 388, Score: 330
# Iteration: 389, Score: 687
# Iteration: 390, Score: 180
# Iteration: 391, Score: 269
# Iteration: 392, Score: 223
# Iteration: 393, Score: 305
# Iteration: 394, Score: 156
# Iteration: 395, Score: 273
# Iteration: 396, Score: 69
# Iteration: 397, Score: 270
# Iteration: 398, Score: 202
# Iteration: 399, Score: 368
# Iteration: 400, Score: 434
# Iteration: 401, Score: 473
# Iteration: 402, Score: 159
# Iteration: 403, Score: 274
# Iteration: 404, Score: 313
# Iteration: 405, Score: 439
# Iteration: 406, Score: 558
# Iteration: 407, Score: 822
# Iteration: 408, Score: 179
# Iteration: 409, Score: 268
# Iteration: 410, Score: 424
# Iteration: 411, Score: 183
# Iteration: 412, Score: 363
# Iteration: 413, Score: 264
# Iteration: 414, Score: 692
# Iteration: 415, Score: 682
# Iteration: 416, Score: 266
# Iteration: 417, Score: 243
# Iteration: 418, Score: 318
# Iteration: 419, Score: 220
# Iteration: 420, Score: 299
# Iteration: 421, Score: 562
# Iteration: 422, Score: 170
# Iteration: 423, Score: 99
# Iteration: 424, Score: 404
# Iteration: 425, Score: 420
# Iteration: 426, Score: 572
# Iteration: 427, Score: 397
# Iteration: 428, Score: 207
# Iteration: 429, Score: 214
# Iteration: 430, Score: 489
# Iteration: 431, Score: 833
# Iteration: 432, Score: 717
# Iteration: 433, Score: 238
# Iteration: 434, Score: 204
# Iteration: 435, Score: 228
# Iteration: 436, Score: 192
# Iteration: 437, Score: 144
# Iteration: 438, Score: 257
# Iteration: 439, Score: 460
# Iteration: 440, Score: 284
# Iteration: 441, Score: 187
# Iteration: 442, Score: 273
# Iteration: 443, Score: 199
# Iteration: 444, Score: 177
# Iteration: 445, Score: 326
# Iteration: 446, Score: 285
# Iteration: 447, Score: 116
# Iteration: 448, Score: 232
# Iteration: 449, Score: 271
# Iteration: 450, Score: 192
# Iteration: 451, Score: 286
# Iteration: 452, Score: 395
# Iteration: 453, Score: 529
# Iteration: 454, Score: 462
# Iteration: 455, Score: 233
# Iteration: 456, Score: 302
# Iteration: 457, Score: 900
# Iteration: 458, Score: 393
# Iteration: 459, Score: 210
# Iteration: 460, Score: 150
# Iteration: 461, Score: 183
# Iteration: 462, Score: 573
# Iteration: 463, Score: 576
# Iteration: 464, Score: 187
# Iteration: 465, Score: 479
# Iteration: 466, Score: 1225
# Iteration: 467, Score: 373
# Iteration: 468, Score: 151
# Iteration: 469, Score: 203
# Iteration: 470, Score: 228
# Iteration: 471, Score: 193
# Iteration: 472, Score: 276
# Iteration: 473, Score: 617
# Iteration: 474, Score: 1241
# Iteration: 475, Score: 364
# Iteration: 476, Score: 523
# Iteration: 477, Score: 172
# Iteration: 478, Score: 221
# Iteration: 479, Score: 234
# Iteration: 480, Score: 212
# Iteration: 481, Score: 146
# Iteration: 482, Score: 666
# Iteration: 483, Score: 793
# Iteration: 484, Score: 257
# Iteration: 485, Score: 561
# Iteration: 486, Score: 187
# Iteration: 487, Score: 526
# Iteration: 488, Score: 106
# Iteration: 489, Score: 146
# Iteration: 490, Score: 48
# Iteration: 491, Score: 358
# Iteration: 492, Score: 324
# Iteration: 493, Score: 274
# Iteration: 494, Score: 166
# Iteration: 495, Score: 383
# Iteration: 496, Score: 150
# Iteration: 497, Score: 217
# Iteration: 498, Score: 157
# Iteration: 499, Score: 371

# %%
env.close()
